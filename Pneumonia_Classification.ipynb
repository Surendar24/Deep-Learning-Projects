# %% [markdown]
# <a href="https://colab.research.google.com/github/Surendar24/Deep-Learning-Projects/blob/main/Pneumonia_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pydicom
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pydicom
#   Downloading pydicom-2.3.1-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 62.0 MB/s eta 0:00:00
# Installing collected packages: pydicom
# Successfully installed pydicom-2.3.1

# %% [markdown]
# ## Introduction
# In this notebook we will preprocess the data for our classification task.<br />
# We will train a classifier to predict whether an X-Ray of a patient shows signs of pneumonia or not based on the RSNA Pneumonia Detection Challenge (https://www.kaggle.com/c/rsna-pneumonia-detection-challenge).
#
# At first we download the data from kaggle (https://www.kaggle.com/c/rsna-pneumonia-detection-challenge/data), by clicking on "Download All" and extract it afterwards.
#
# Acknowledgements:
# Wang X, Peng Y, Lu L, Lu Z, Bagheri M, Summers RM. ChestX-ray8: Hospital-scale Chest X-ray Database and Benchmarks on Weakly-Supervised Classification and Localization of Common Thorax Diseases. IEEE CVPR 2017, http://openaccess.thecvf.com/content_cvpr_2017/papers/Wang_ChestX-ray8_Hospital-Scale_Chest_CVPR_2017_paper.pdf
#
# Original Source: https://nihcc.app.box.com/v/ChestXray-NIHCC

# %% [markdown]
# ## Imports
# * pathlib for convenient path handling
# * pydicom for reading dicom files
# * numpy for storing the actual images
# * cv2 for directly resizing the images
# * pandas to read the provided labels
# * matplotlib for visualizing some images
# * tqdm for nice progress bar

# %%
from pathlib import Path
import pydicom
import numpy as np
import cv2
import pandas as pd
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

# %%
labels = pd.read_csv("/content/04-Pneumonia-Classification copy/rsna-pneumonia-detection-challenge/stage_2_train_labels.csv")

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !unzip gdrive/My\ Drive/data/D4.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/2e4b20f7-69c4-4680-9c8b-6984c195b1cf.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/33e4f74e-b8f2-470b-8815-6ee3e94b8590.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/c60a0502-26cb-40a1-8343-43625a3c4e3f.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/bb1a546d-12e6-41e8-b602-768a0e499569.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/46da5af2-a757-4670-90cb-5cc59c1e6d87.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/0d5bc737-03de-4bb8-98a1-45b7180c3e0f.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/012a5620-d082-4bb8-9b3b-e72d8938000c.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/3ed5e37a-df95-4bf3-9ea9-fab48fc42f86.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/ce649e4b-1461-4c34-908d-b0561ac155a6.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/32bba2f6-0701-4646-87cc-9ddc27439be4.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/d974dbc0-5e7d-4aac-bda5-f29096aeeb5a.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/5b0c3016-c88d-4b19-82f8-bee204b8e12c.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/c762013e-3fd2-4301-9af3-9a3b10ad1fcd.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/6f37008d-c8a4-45b0-a1cd-7b215df62cfc.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/bc41e91e-506d-4ff9-8dba-3fd085f38491.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/a108c5e8-49d7-4ec4-ac83-a5cb0442e536.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/34a86615-92b7-4b4a-813b-9e62e51b6d10.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/d91b519f-9216-4ff9-9e2a-3356bfe4e391.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/3f167f68-6cde-478d-8e78-9ae22529c22f.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/b1a975a0-4a69-4c65-b761-44a506b86be6.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/50d934dd-f974-48c2-b021-f40b9539051e.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/17802f46-96cb-4658-ae3d-16be89ac69f5.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/3b253e33-a932-4d96-a8fe-f3a5be6b66a6.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/ec93d206-ec61-4e16-afc4-898f754916fa.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/77f96630-7a12-423e-a4e5-a5c5db11fd8f.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/3daf4e31-32b6-486d-8091-4747a365cf60.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/b2d2ef9e-fabe-4e70-b36a-e1e62e0a00f2.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/bb65756f-f78d-412a-b5e6-c7fe81c9eb4b.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/8c8a3a36-3c8e-4a19-9821-cc7467d962ee.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/a94ec882-bcc3-4c59-8c6b-2d690595a04d.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/49b96a4d-7bfb-49f2-a31f-932371038652.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/72dbeeca-38a3-4375-942a-9c3b098da64a.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/3747c54e-e425-451d-90c0-943e99b873d4.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/ace3688f-2479-4468-9759-1e9a1fe02d6f.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/0c391e0f-9927-48ce-801f-02eb000f72c3.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/c7024796-39ed-4eda-906d-65a1fb5d5c52.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/f02e36df-ac4d-43f1-8001-3e0494145b0a.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/aa61804a-c589-4027-b85f-4eaf8282e3a8.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/b7f61871-5e78-4b27-bcc8-7c452c4c746a.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/ba278d92-c5ff-44f4-b1b8-7d3454df7e54.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/6e5571f8-ebf5-41f3-88e3-2e78a6dd5f0f.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/5c832734-cfe3-4602-9b28-f71416e62fa6.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/b61e3955-0a8d-4678-9746-b7202fd6d777.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/b7667cf1-104d-4413-93bc-49b1e9613e4b.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/36994bd6-13dc-405e-9f98-680a0e5b2eea.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/8a108521-47c7-486f-b172-f1c3c3252fc8.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/591ef0ea-6a2f-4079-9bc2-20c988507809.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/11827075-47dd-4f3c-a7b5-aae992cce35b.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/095d6b7c-fa53-4f06-90b9-5c5f76038f04.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/3482d22d-9a14-4b38-b28b-6f7b93a78e43.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/a7e875c8-2f8e-4eb1-bb43-5a5f7d206ba9.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/c1ffc793-0e31-4396-a0fc-6f7f6cccb28b.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/695e33f8-31d1-467e-add2-f05041880b28.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/317a2577-b48c-4dac-bd52-31286c7546af.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/17e95c76-ae2f-4ad9-b713-08b617d3c9bd.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/78dba4d7-e138-4d40-b6a5-ac2d8c65dcf5.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/3d413032-b091-4f90-a131-17bc1eeb0647.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/a069b05e-0957-454f-af9b-8daa65d406d1.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/0cbe5298-68a4-4de0-a693-46eb8e8858ca.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/c3b0adf1-3768-412f-a3b1-7a7f2a6dc928.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/5bcc2f5b-46d9-4e87-bfc5-b4808ec4f13a.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/07349035-d546-41ec-813a-612614536f5a.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/c4400499-489b-4867-973a-06747a8261bb.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/6db53e07-4656-47e7-bed7-5782fd117f91.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/78ce6b9a-db15-4576-8e8b-4c52650a457f.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/b0958738-73d0-47d5-9703-0de86944e0da.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/98cd0b89-202e-4b22-83e3-ea843488ea6c.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/bd9af100-1805-4e0a-8875-4a4b7195f0d8.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/ad5a2700-3388-499a-8584-d811cacac4ac.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/0bc7f47a-ecea-4b66-811e-096004721a63.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/93c1ea7f-20b2-4860-9beb-fd0ad2f54bd6.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/085a25eb-1ebd-4bf1-b320-7833e7c37553.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/85682fd3-9d19-4b37-a663-6071cbfb82af.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/99a1a344-cb16-44ea-9d2a-a9daddbddd26.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/38dee80a-f2e3-41f4-8a72-1f89f4a9c003.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/36491026-0b06-429a-97bf-644518295055.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/c2657014-120e-456e-97e5-1adcdb908b73.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/be653a8a-5978-48b3-9101-91e35a15e6d2.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/b9e89b84-5cb2-4005-b654-a3e13c544923.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/7302e6f8-50b1-4b00-a299-c5d1dc4c1c76.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/5e528963-b34e-4605-be13-8faaa2b0c65b.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/c2cd822c-a98e-451d-8600-e52f50d65c28.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/c27d0e06-ef8c-44ca-b4cc-a4113b723570.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/3c6cc4e8-ab85-4053-9844-4f9eded69eec.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/71c5e5fa-6d92-44a3-a9fa-1e3421b27a07.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/1614564a-fe0d-43dc-87ae-299d859959f6.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/32c41ed0-6704-465c-94d3-3073b9b4415e.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/df21b6dd-32b7-4edd-8b7b-fa1a35e0c043.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/3dc8aa2f-0e49-47ba-9eaf-1a3bdb189ada.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/d01efc31-f83e-46dd-a3a1-1eb73f60ddcc.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/b0172af7-ae97-41a4-a848-cdea0fc1866b.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/b9250558-2525-459d-894d-65355b4cf432.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/c3b185a1-bcb2-4cdb-a4ac-1aeb2668751c.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/16923fe0-5e98-4bcf-92e6-65d10161660d.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/192f8bc4-1d12-4b3e-84a6-d94f77928faf.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/9b16af6c-5f7d-4550-a641-e41460c820c8.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/58508fc2-0fd8-4c2a-87ee-a3bdda7cd9ff.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/584dfe20-9b9c-476f-80a5-90204394360e.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/c3768927-0d7e-4624-bf5a-3eea2011a5c1.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/79e66b5d-e740-4fea-b9be-8cb2c75fd375.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/ad233e1a-853b-4ad8-951f-a756c3cf2d53.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/bff6b953-95d1-4a08-9d79-c3b43fde59ce.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/3d0964c8-b41f-4e3b-a871-fbaca943558b.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/9de7304a-bda3-4aa7-8002-c7b1b662745d.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/a0af1a60-0f1c-4d53-9a71-dd438aa06b70.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/cfe768fc-4a0c-41fb-b3e3-86229e2cb94a.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/36fb7333-2dbf-4be3-a424-6739b2090dee.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/6a5d55af-fc99-4957-9404-f08e4150dc55.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/73bc84c5-99b9-4e31-b8db-e3707aaf3576.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/162b17de-b15d-4122-9352-ec3445f61f35.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/dc7720ba-e9fe-4680-8304-bb149bedf128.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/080f2b35-fcd5-473e-864b-a7dea3054cc7.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/37290d29-2a81-4c9d-aef6-15eea1376e0c.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/0b323a31-28e6-45b2-a07c-cc9b60571053.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/bc34f68f-0c2b-4e9e-be5e-377f531a1207.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/bda1d8b6-2a74-41c3-8cef-3ff7864e4613.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/05fe7d73-5c8c-4349-88c4-2071a00d6d81.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/5f60e810-6c24-4c0f-b768-ed371e544a10.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/ca5defaa-00b9-4904-87dd-debcc3ed3d77.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/85ae17cb-e7dd-4d77-9bf5-8bccdae0f9a4.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/bdef94bc-4e2e-4df3-b06e-126aed15846a.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/3a925cdd-891d-42bf-9ce1-30e7c95318be.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/971befc9-5a0d-4bda-acb5-2cebeaa8163e.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/7b7d7bf3-0684-465d-9a74-f51887685387.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/b50cbd3a-14cb-46bf-aaff-ae2cdaeef739.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/ec910555-f698-4536-aff7-7fa9d3405d60.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/b551156f-a0e0-4895-9bd5-c4e6307f077a.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/0638709c-d31d-4a59-a9e4-fc408ae36145.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/36bd8ee6-cfb2-48ae-a57d-dcea7ba8deec.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/55891cc7-b8ed-4b22-8bf0-a6039dc53727.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/b7e6c8a5-c115-4a0a-9838-e74604a685b1.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/3a3e5ddf-0b42-4c84-b13b-8e3ac1e8b2c0.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/48029094-265a-43e6-9e29-455237085578.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/7adb12c0-b1b2-402e-9c58-5a8873eef61d.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/f11abf44-b267-458c-ae67-e1167124f5e3.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/d03f855d-a0b8-45b9-afdb-8844186c11eb.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/bba14241-9fd6-40ae-91f3-945af76178aa.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/f146bd0b-415f-45eb-b0c5-16d34a47c486.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/a0a8370a-dc3f-4f70-a440-e3fa9827928a.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/d21e3291-a64b-405c-8a71-8fae7041b138.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/b0fbd4ac-3ab4-44fe-9c2f-4179bbf4260e.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/b4abc0a4-600c-4834-bd71-c9dbb21eaaf0.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/39693e31-b11e-4cd5-a626-2862cb0ede1d.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/975aac17-f7e4-4b6c-a669-e73b0bb5caef.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/375e3962-cb81-4f04-ae25-f74d92320998.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/7625412b-fbb0-46d7-9f7d-00b436cc467a.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/737030d6-07d1-43de-9e11-82b31accd240.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/1e8fbc6f-08f6-4801-b437-69d9e5bde269.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/6f3177d5-1942-460b-aece-51414a64ed5b.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/07d1a89d-351c-4a75-993a-ba315142b419.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/bbdf6d54-a58a-40f7-b7fa-8f3eaf22e414.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/e5368a74-3005-4ebb-94a3-6e859b9ef3fe.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/6f3953f5-5129-4a74-b8f9-cf386f919930.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/c26c0bb6-125b-497f-a3fa-04a5729b36c0.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/483d087d-712d-46eb-8f5f-eaa1a53ec2ed.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/ba1e3912-82c7-4e15-9c46-46fbf780b2d9.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/8ce28cb3-1184-4792-b774-229fa7dd633e.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/43e51c0e-1a39-4476-bb12-c04d89783b8b.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/8a61a6c6-b600-4eb4-9bec-ea32804c03b2.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/dd830a3b-db9e-42bd-8d3a-8d52f40ddbde.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/62ce6e7f-e6f9-400f-81aa-1efd9301e256.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/a8cb813b-9d3a-46ff-8003-053271cdcc9a.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/ae59f8e3-455f-4f96-b686-465a38a0f3e2.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/db32f09d-b7f5-424b-a393-a10cab691038.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/bd94199f-bae9-4689-b509-7d427ab79c3c.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/e2efa725-693d-46a1-9abc-545ea633794c.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/3dcd38ce-8adc-4c9b-92f7-768a33611f57.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/74075cca-a426-4710-92de-e23aa74b76ac.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/b4857f8b-e6af-44da-84d3-ba3608ca7cb2.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/98b74eb1-7a17-4c4f-ab85-a93ac598c1c1.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/65d36e7a-f867-4bbf-98fe-f6ce549cae87.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/beb63eac-b9ba-40b5-89b1-8aed84ab43b6.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/9a61bc75-01c7-496c-b5a9-b4ad264b7885.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/419e1001-50d6-40bb-a448-57abdb795117.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/9a8d7f49-ec4d-40db-998a-a1b81ad9ac52.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/adf7dc8f-19dc-4543-8aea-982cfa21629b.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/ebf2bdff-9e1a-4365-9010-738d58b62944.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/a0ca289b-6e0b-433d-a45b-8f86044e1ae1.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/c3ed4cdc-183a-4b8f-a51f-d915d912abab.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/40f57a2e-1b3c-46fb-9350-558e34b8f4e9.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/9fbd7b9f-ef1e-42ce-b594-1a3f017fb604.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/6a078738-03df-4e3f-adb3-d203baef1e1c.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/42705f2c-8bdc-4a9d-8e13-864b0a89be21.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/8d4ddcd5-75ce-46b9-acba-f8c7552603df.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/b18a2d86-3e3a-43ec-b9f6-0fd249bc1a0d.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/b815bf0c-9150-4a9f-acd5-d278a35e505d.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/b41dfb17-3773-485b-8da6-c29a2bbfbe3a.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/c236f38d-10dd-4f33-bbe9-c849c297806f.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/a1aff3c3-4eae-40ed-800d-d5aa693e1132.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/b6fa6fc8-812c-4110-9881-5a5f8f2fea65.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/24dba8ea-22b9-4a3c-84ce-6bafeab8e6d1.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/ec09ddb3-9b0b-4749-9e0d-f94a4a7e5fed.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/e94d8646-1703-44db-9062-c9b305e238f0.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/96f34fa9-0e56-4fdb-bfd7-781d8c453bcb.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/816cef8f-cbf7-43c7-8386-609bd95c78e6.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/2397b2f6-3dfa-476c-89ea-e9992c5bd9a9.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/49300dbc-f609-4c80-be6c-808222542479.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/8c10567b-8e66-4f35-bc42-d2698469e586.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/5623a68b-8f2d-4295-bf4e-2f3a471cb84b.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/5871bd61-108b-4c53-bc24-c20522d56061.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/f137d0ae-b2f7-4fd1-916d-773d4695b626.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/386334b4-06db-4a66-a7f1-9d0a6d9f2cdb.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/aa85ecc1-f7ae-4a76-ad20-aa660f99c186.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/afe1b6e2-203e-4ee5-856a-2f205d8bca2a.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/6f5eb191-d7ee-472e-b08c-e6975896f5c4.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/0c1d54d9-0197-40d9-9b07-d99b1e8aa8db.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/af335d18-feec-4942-9831-3e25ca20e7e3.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/464d7389-cbe4-46df-a2fe-b5c9bfca664e.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/916d9880-914d-49da-b1ee-011714c9c1b7.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/833d97e7-d927-4ff8-b7ff-6a28f629b6a9.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/d8e8af62-c7de-4f67-a5de-d38507419763.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/3687784e-47a5-40d3-aa45-5cae7dd23e8b.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/e5e4f0cf-58ec-4442-a54c-96d5d29d8f0b.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/bdbba1b5-1a3f-4ee4-9044-565baba3f976.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/d9a6fe09-9ee9-4d64-bc42-cd903276f513.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/a36d17af-dcd7-4414-a701-3ef7c462e05e.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/0c153d93-d65b-4d3e-90bc-8b26350e3476.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/d471c394-f44a-47a4-9e41-6a651b8916cc.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/3de7efd4-d074-4fee-95d7-4718e4d7df91.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/948ad418-c89a-4476-8152-1e956ef27cbf.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/5bab9e56-d8ea-47a2-8848-fd768e4a52af.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/91d27278-e329-4065-bc04-1e69f9ee2db0.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/3ea67d3a-90be-4e77-a745-a9e323189097.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/181f55a1-d776-42e0-b2a1-ab2e73dc31a2.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/aaacdecb-a59f-41d9-ba6f-7e02185c2326.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/a288ccb7-b58d-4411-a5da-6dce74957e74.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/e15fca95-ebf1-4b48-b94d-aa5b702369b5.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/b680c111-22a5-4ad1-94b7-34e866815e79.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/48e340be-50e5-4495-9a4c-2f934435903d.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/cba00aeb-4389-4de9-b374-56b412361c46.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/63450918-0bbe-43ac-9d0f-22bed387dfdb.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/5b795813-0205-4879-9bcb-69b7a417316f.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/bcab0525-079e-492e-8e20-c51c779884aa.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/0812652c-3d92-4cda-9a06-c9d232e0b96d.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/85fde190-a997-4f2c-8378-61749288bb46.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/7d674c82-5501-4730-92c5-d241fd6911e7.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/a6c364d2-b2d6-4b0b-a439-40b992ff65c7.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/3d8b3936-bbcc-4700-999f-0c2129d07997.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/464a8cdb-4e55-48de-b61f-72edb6992e0f.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/9ed655dd-cc93-4bde-be51-804bac051f25.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/e6237a2c-514c-477b-8e79-727ebb9436a3.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/aa2b8e03-8968-4d9d-a783-e64d9bca1d15.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/97d7ab4c-257f-4cf1-b582-d37ff1e2fb4e.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/2993d607-03e5-45ba-9d1e-7e5b418b5a24.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/e212adf7-2a29-4069-aa94-8ea5d366d0eb.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/a3ff8160-0b83-4f41-9880-201c7981a2e5.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/b77ab795-de76-4715-b371-eb7be54b584c.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/336c9afc-e140-4d5e-ab50-7b11809dbc1f.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/a887251c-8046-4ff2-b5e5-9ef155ef94a7.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/28fd01f3-ea55-450e-934c-df01b11cfbc9.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/dbea4851-d8c8-435f-834d-b0895ab0475b.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/eab6d0b6-1bba-4c26-a208-507c54d14016.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/e01ef6c8-20f4-48a3-8917-686da0e5b454.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/78228039-bc86-44ce-8a13-57cf49ccf493.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/ae794223-db3f-4b8d-a307-a5cb1ac5eb57.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/05b91b32-5635-4071-b45d-6a73f8eea918.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/3fdcd01b-1029-40c9-be8a-a72876d0323b.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/c10053b8-7bc8-4d8f-99f0-92d86a97ee2e.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/66c52ba5-c91d-4f0c-af96-18148fd9dd66.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/5759f979-a582-4eea-8056-cc17c85bb984.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/8736a34d-c090-422e-bc99-6281271d6554.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/a541be19-c9f6-487e-b615-d15042a246b1.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/6ceb3cd1-dcfd-44ee-b02a-0cf6e981b081.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/66ab31a6-be10-4f4e-ad4d-b4aeb9371271.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/de0753bc-4086-4b85-a0bf-ca66c5832ce3.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/c4acd677-ae5e-4b23-b888-2e8e2e1c3996.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/d7131b83-ef4c-4a0a-b1a2-d09c163bda48.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/0ebc8268-df3d-45d8-8ee7-b34880c62830.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/e77e8d88-11e5-4d15-8dfb-abcd5c09c9f0.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/e0227184-955d-4bfd-8eeb-0bc0b2a21a66.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/3a902c1d-e41b-43d3-8484-4c0d92a30271.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/5da671da-84f7-4847-9995-334ecf044f86.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/c4e96c53-34f7-4607-bab4-45e982079b2b.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/bb189459-2735-44c6-a344-a645a9721dfb.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/6ccf77da-c917-4fc1-8bf7-f0e7bfd3acf4.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/a74060c8-870a-47e1-9bc9-c1226caf9a87.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/bc1c9e32-2815-477d-8dcd-6352dec8749d.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/94fd8652-cb5a-40c6-9c5e-e429de9e8715.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/3f79f27a-6d84-4ff1-88a2-eb05ff9a5f57.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/67b8ef8a-5285-4eec-88c8-8f4fe53f0f6e.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/37f17069-62ce-42ff-9fa4-d6a1056bd075.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/09c48ba8-4f0b-483c-85ec-9246d7cc6177.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/b18e4375-e20d-42e9-a545-a62294135c07.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/15df7a1f-a2a4-4d5e-8771-3280fa1184c3.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/c39c065c-40fb-4920-9f9a-36ccbb212c0d.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/3c8ebe92-dc43-48b9-bbfd-03dbc128d2af.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/ac29e848-bceb-4233-8a07-14778f17d575.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/0d2bc8b2-2340-4deb-b29c-ae4da8fa5764.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/3b9bcca1-0ca9-4e93-ba0c-0a6ae1342726.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/5e3c7f02-5622-4d7d-83a3-6555eb5839d3.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/d947215e-c4c5-4907-8d47-0735a0ba4fb9.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/3a5c1a62-279d-4c69-b3e5-394e34518b73.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/2c0efede-becf-44a0-b762-10e97cf178de.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/aff2efe8-0cf0-4789-8ec9-b15d10f32c69.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/3156adea-d1f0-4a8e-9dfd-fc1d9bf5fc1f.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/31714284-24d2-4e29-95ce-1342164502fb.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/b4989ff4-3c1f-4de9-8df1-cd50c211273a.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/393288db-4195-4b6b-a380-053c20aecf81.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/ba07f107-5f57-4c63-8d82-e19b30e3e72d.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/4e31aec9-ea07-47c2-8712-678976de22af.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/7fb3e6fd-596b-41e7-815b-b2be3f856184.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/14996682-7fb0-42e1-a925-ab2a639bae18.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/7b56e6a2-be01-44b9-9ccd-a70cd5c8fbfa.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/1738d7da-d93e-4f81-aefd-a1adb148664d.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/20f39b8e-be82-4f24-8791-651533a73184.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/a458d820-3a26-4f46-ab7b-28f42a1ff4e0.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/a8521ca7-b65f-42e9-83e2-f3dddf811eb3.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/3251dea8-4f74-4f4b-8f56-167b0213414b.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/a23ac27d-83b3-48b7-837a-dbbe83752ce3.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/26d622c4-c7ec-4952-9210-7b2a2144cb79.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/be27131b-ca91-4ba0-bf1c-7b6f9f57b4b0.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/32721abb-10c7-4797-88c6-bf47d32e95e6.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/34be1f4b-2863-425f-9f8e-6dc21579575a.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/395cb95f-700c-4a77-89f1-dcbddf957552.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/8d48694a-f998-4043-bc98-63a3c18527f2.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/b8397df9-1bd5-4961-b756-978ff4aed6cf.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/ba07114f-788c-4779-98cd-1190bfb6bdc2.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/c32611c5-e546-4021-b244-4a6d0503787c.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/17a1427c-70b0-4383-b5f3-a2b5f1ec0691.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/739bd043-d62e-41ef-bf20-20ed762dca13.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/d16488a8-5cfd-4051-bb2c-d7f7c88009e2.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/bacb9e6d-ad87-4841-99e0-685aa0249bbe.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/bcbf06b4-ed44-48aa-a498-a7147c063d4d.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/7834a7b0-6064-4f9c-bf5c-a526393af472.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/0ad9934b-bf35-497d-8082-1ecbc955d6de.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/7b2d7682-0c3a-4ce5-aae4-d06a5ab14ba9.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/e6295ee0-bb33-49e3-9376-8b78f5a3fc52.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/3ef0d810-9e16-45af-a3f9-8d9bb371c308.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/b99ae612-3a2b-4575-a6cd-b00c2e27c56a.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/36946b92-64ac-4bfd-9984-e3f9b8b95bc5.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/59751586-7297-4037-a4a2-faf0a96cb7c3.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/3768dc07-b49f-4e4d-8233-5dda9692ca68.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/632a88aa-2123-4bc6-92c7-b3dd7c91224c.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/7508399d-307f-450d-8f47-f24930ad6fb6.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/ed38283d-165f-481b-bbb3-5532450b82c1.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/c424b446-ced5-4ab5-a097-41b6e496146d.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/b6138fc8-c652-4b7f-978d-895d10b0a0ea.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/c241425c-418c-4958-8a18-c3425fe03f03.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/eb061685-c06f-400c-ab24-a7f702684c02.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/8dc8e54b-5b05-4dac-80b9-fa48878621e2.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/0742a7f3-5f8e-474b-bd1f-0ba8ba9a6b19.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/e0a1ffef-682a-4d15-a232-46439d4e4d9c.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/bc92c935-81cf-4e5b-8edc-381c0327072b.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/edfb87ef-944e-42df-a5f1-49b415d1741a.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/883ba5e3-307a-46ee-9bb4-674c33c0f182.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/9f377ef1-a9b4-409c-8e6f-94199ac19a75.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/1b4ccf65-5872-4694-b441-599471b7794a.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/9ded4d8b-5e88-4470-bb20-1d55d76d6658.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/87a3d945-d417-45a8-9f57-08cdb83e4e8b.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/b0047aab-84f1-44b7-b485-37df40388101.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/50f7689c-9b02-4553-b96c-000d70d45d50.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/68fce9ea-3122-49bd-8968-85e8f9315c83.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/60ae6dde-b322-4c93-ad89-1b061fa48098.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/359ce100-a41f-40e2-ba95-c91b83725a35.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/854fee36-d54c-4cde-904d-ab77f5e2e091.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/d815454a-5088-407c-8822-af205bec401d.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/3ead6e4c-1d18-4eed-98b9-a1ea9412751b.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/a8935cae-155c-4200-afc5-6fd74dd1b31b.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/3ddfe89f-2b00-49cc-ad50-30ac45c8aad2.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/b1a24561-8456-4032-9ad4-23a6d5a2b999.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/3ba80992-3ec3-421a-97b8-354f1a5dbae1.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/1839045f-af6a-430b-8771-c984f87799b0.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/b0502b9f-b85c-4cac-9e8f-325ed59315e0.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/35061124-9245-4434-b165-b89aef28bb75.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/3d62329f-40d2-41e5-bcdd-c7eabc33f516.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/a2a84bc3-c75b-4df6-840d-e118b61594d4.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/b2753475-d0b2-4dde-8a7b-311e1db27397.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/38247d25-1b31-438b-a0b1-53294160846f.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/3d59faf9-6b80-42e5-b5fb-95048344c92a.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/75cf69a5-bdc1-4ef9-8937-2abad5bec289.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/3b66da46-f0a2-4e41-bd6d-68a8ba799708.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/8106073f-c91e-49cc-bfd8-c191fe793638.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/99dcf680-1f54-4d88-aa29-d909be9e82ff.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/6a007557-7c16-4726-b91f-2da91ee8f798.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/909719b9-a1af-41a2-8ce3-bb99200a5cb0.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/0695a0d8-d4b6-4dbe-bc04-497897e4516a.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/3a95e2d5-ec7a-4020-a48c-7d61fdb3d0af.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/793a56ab-71fd-4bce-b9fe-d25c63d93459.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/9d1ea51d-29fc-4aa1-a4b0-fa1f1c979d0f.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/9e9cf557-f329-43ed-8095-dc66bc667c28.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/2a15b6f2-2a17-454d-b14c-ba1bb4bd79f4.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/e89dadae-bdbf-4f2e-a4a1-d2d56abf0d48.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/3d505bb2-544e-4e2d-8859-ef33bf31c49f.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/8fac10c1-1b23-447b-9169-ea50cae270c2.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/b35a3c89-f199-4924-98f0-8d5beea4b41d.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/728a62fc-4310-4aca-9d68-72c8a829d69e.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/b1c607c2-6651-4bfa-8a6c-ba85c349927a.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/bbc0f839-6707-42f6-9e56-c3f555d6b9c0.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/ab5af9ff-8001-4442-af29-693abdb98e14.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/94ce6989-c700-4a9c-b3c6-8c5a512b6ff1.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/0ae82435-399e-4cf1-9d78-92d1c184178d.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/5e0d73fb-b207-4bab-a1e5-9d6b3163520e.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/99772300-b5be-44cf-b8a9-682247e5e8c7.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/7faa429d-99b9-485f-8642-c54325982eba.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/44b60029-338a-487f-b4a3-7afcaa4f1e41.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/9a3e1197-91f6-4e4d-9aeb-fcde3483849c.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/ad4d16e5-a851-4327-b9fe-5977da445669.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/8047b765-c93a-4059-8a09-9b1e809809e7.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/3cf1aff4-8d32-498b-a7fe-d2a6a5292d3c.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/8f202a05-d9d3-43c2-aa4b-0ab8939f0607.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/759a11de-da95-4cb8-a373-ab848ae74171.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/b6271674-f13d-4087-ae03-d6ae35381dfc.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/859ec41e-8eb9-4aca-a0bf-c17a0984b894.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/e79c364c-a4a4-4201-b5fc-4b46701b5cf4.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/47a15caf-d139-4fa3-956d-6f8afa5ac376.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/98833b28-3925-4098-bf44-c81a9e687838.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/d20a1a10-d569-42f7-90e9-882f7331e3ff.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/b78f2713-e211-408e-a810-e0568fc0f0a0.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/1414c7d6-dff3-453c-8322-b25bb5899d78.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/e85b9e5a-ea0c-4fcd-8e7f-2f8699923099.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/de9d40a1-45ac-4ec0-a9ad-7c3da394fbfb.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/9e250ad1-581b-402a-a7df-dece604e7764.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/5f016f29-19c6-4895-905b-354bae107073.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/8615dbf0-431a-4b5a-abd7-6811fb272ef6.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/e1297bf9-390d-4d7e-b902-4b02005a0d4f.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/e07110c1-7afa-45b3-8de5-901f0a96e394.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/7c909599-24ad-4164-93d2-0adfa96ec86f.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/e1a10525-e325-40e1-8709-2a9bcf7ad290.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/e56de97f-aac0-4a7c-8ddd-f861cae269f1.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/6129213e-1ab7-465d-a84d-e871246fa712.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/06d3f696-82ea-4c71-b162-f18b3e0eeeac.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/a6236ddd-6367-4569-b5f1-07d2df9390ad.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/c3e28b77-4477-4e36-89a7-ec0713349d4b.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/ae5bbcb2-8f3a-4f5c-a7b1-1ecaa6a7a967.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/e03b2ae0-a0a7-41d8-a6b1-dac421515a27.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/91e5caec-93a8-4361-abbe-22fa1bd60c6f.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/85708ae1-d69e-4153-bdad-ced31dfaf486.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/72a10e64-2d93-4b61-8b90-8efef7284ced.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/4c665597-adbc-4583-9d9a-20cc0d8d00d0.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/79df0c01-2397-4d31-8318-435a1c80ae47.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/9115e87c-7fc1-4d6b-9cdf-436ea13c8c33.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/16fecf77-f64c-4a80-94e9-4eaa27b78aec.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/3e62e51c-befb-4a66-b28e-fc469b19e4a8.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/a684b3b1-3d9f-4288-9095-cb5b28aa2eda.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/aaa04d93-39da-47c1-8736-a1a2c85114af.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/d4b3478b-d430-4c89-95b5-1c1c27c8eb71.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/5904aef8-6b8c-4e45-a8b2-8ed4a369079f.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/755233cd-2ad2-4cbc-b927-97243e46135f.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/a6905106-5479-4725-b81f-532376d24222.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/6f316d9f-5bce-464a-997e-bb04596b9844.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/1623088d-9f8c-4910-b681-c81fef043fa3.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/93e19d77-ce48-41e4-b78f-b873525673dd.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/ec55e4ab-ecdd-4265-a5fa-d84ee0af1e0d.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/9c3ec0a7-6816-46e0-b797-8412bacea535.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/7332ae2f-48af-425e-971c-81092e98187d.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/6f0d2ff9-c0dc-48c3-a944-1f18dc185e1f.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/087bcaa5-2477-4111-8390-fa5f2dec4852.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/train/1/e0091a61-2aa3-42f5-8a0e-ad47a9ff7c80.npy
# ...
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/0022073f-cec8-42ec-ab5f-bc2314649235.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/13bf28d4-fa19-4ba0-966a-938f676d6d04.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/3036ca10-8d42-4749-81e2-8ed235a6a567.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f5257a21-9efd-491f-94da-5cbce76d8f95.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/2cd0cbc4-bf35-49de-963e-8ee3fd08ca75.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/2c917d3a-95cb-4c11-802c-f83e28cb37bc.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/fe71c437-e46b-406c-8870-3b2298fc7d3a.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f5b9e64c-e373-4ccb-806c-850c5a38dad6.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/220e0278-363d-431b-8094-1e28085ddb0f.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f9471bff-686b-4d20-932b-bb0c76c8b77f.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f454d325-7967-4c13-ab5f-139dc0f1ecbf.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/ffa424d2-6e6b-4eed-93ab-7551e8941215.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/2f200e3f-8e4c-4675-948c-8226cd65163a.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/fde9b6e5-382b-4fec-8406-70a279a4b696.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/1accb591-63ca-462d-8bd8-83be3cb91df2.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/fe518d2d-28a1-42eb-918d-16f7bc6039bb.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f919d3cb-dc68-46b6-8c29-2d3914fbaec0.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/0572881e-d1dd-4757-a54e-b240b30da946.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f263d63e-1715-4bd8-af5e-fa4e824fa55b.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/25ba8a50-bc9a-4ca8-81c3-9f635f52243b.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f23907b3-9638-4986-b471-b4f2873f6504.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/c08f10a9-1c81-4c81-b411-a53c7b51f20b.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/23ae7f52-f3be-4b6f-ba8f-ac2a72f433fc.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f7250628-0db8-4baa-adbf-fd694cbd3b7d.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/025d196b-cfa4-44a5-9e31-0f73dc3b318f.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/fcd159f4-21d3-4169-a94b-95a2b5ccddcb.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/0e533087-5959-46e5-9fa5-95761a7d472f.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/018951e6-9fb3-4e92-8ce7-e3a018daf93f.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f40574cd-4fc5-43a7-a2e8-8bf66093c80a.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f741a9b1-f5d5-4160-bf27-bf8dbc94cf50.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/2d370cb1-791e-407e-9408-9156664de6b6.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/276e7c3c-7875-41ce-93e6-0d1834a403a0.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/c068a37d-3fe7-4a26-bb74-575ea6be194d.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f7a172fc-a34f-4155-806d-7b0afe2a6156.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/131dd766-23cb-43e2-9653-13033d70765c.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/1c5435c1-431c-4815-a50e-6c20dc2d929e.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/fbab1671-b256-4cc5-9219-79fb47ef75c5.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f4362a52-b9f5-4d96-a6ba-04284a233eb0.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/fd72c1b0-9525-4bcc-b70e-15e1755c1b7a.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/3041969c-8db3-448c-98fd-10ff11dd59d4.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/02589621-9494-4801-99a8-a4e89c1b525d.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f93e4397-1773-4858-8e5d-a449c11a36db.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/103451bb-1f8c-4209-abce-0be7e9a6c8fb.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/fe79ab03-4727-45c9-9c42-813f2b34f111.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f638a33c-ee3e-4179-a095-4fec05ab51e5.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f9230537-bb87-4de7-90f1-73bc730d4b3b.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/2178c094-b206-4fe5-a9ef-d84540996b89.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/c1273696-fdec-48a9-988c-74e57b6323fa.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f9a571b8-65a5-463c-8ee7-db2f3728f5d2.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f50616b4-c6ab-44bc-8a70-28464c77c397.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/fb10f71b-fd9d-43cc-a310-c5b48b7d22c8.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/22ff9ca2-6b24-422a-b8da-6f986a870077.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/1caa4dac-4bac-419b-91d4-cac2d8408ccd.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/11a2e0cb-ee1f-4d53-a211-b8faff6bf888.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/23997b8b-5726-4b2d-bd45-b15fc1c4c2af.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/1015e103-bda6-4664-978d-f761cd2982cb.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/201fe232-cebb-4e8d-ab9a-f41f03bd676a.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/25c915e6-1b94-43b5-a19f-21931faac3b2.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/c1e73a4e-7afe-4ec5-8af6-ce8315d7a2f2.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/fea6191a-f4d4-4cc6-8bf7-5e81bd097209.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f6077569-6aa3-4132-856b-6bdcbdd70cd6.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/1c187dbf-3fa4-4a39-914a-39994b76d4c5.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/1b167f33-a18a-4aab-8a29-2a9d1d41c054.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/2e1956e1-8430-48d7-9888-910934acd22b.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/1a2dc891-713d-4253-ad19-a1e7910ee2eb.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f40ba5da-1ef0-49d4-bb19-492892b41704.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/129a1251-95cf-4663-91ad-4e58bc0b2d08.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f218fda3-c484-4836-867d-b7ad037bfe4e.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f59ae80d-d98e-465f-963a-1064764211f8.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/2f686840-18b3-45ac-a2bb-6140e3b0ac73.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/23aa6468-59f9-4ace-b656-9fea8d64764a.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/27bdb2cc-9665-40ea-a6b4-248a1112dbe8.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f89cdd03-5ea2-4e80-98fb-1d2e57686638.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f979069d-6915-4f84-9b97-345f35ad2083.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f26f795e-e989-40ce-a076-5763295ce46b.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/fe539da9-f41c-404f-bf48-cc20a30a201b.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f743c21e-5876-460b-bbd6-2e2dcca41baa.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/fce56107-c115-4cb6-b340-19f87b757035.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/26f62d1f-5b9f-4eed-af49-d6a48e8ff3f7.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/1dad3414-88c9-4c56-af5d-3a1488af452c.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/fe7f6d2d-9ee1-4e1d-ac8c-bad8d2c4317b.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f6c2c26b-7d88-4709-a874-e85c65358c3f.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f4c7d67e-1025-46e0-bba5-cee068b8bd6c.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/25465a29-78c4-44cf-984d-b3b9477f2de2.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/232f6bcd-2006-459a-9b30-b51beea28044.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f9651c64-a88f-46fd-9ca1-63a55f50873c.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/1b4d9ebb-644e-4602-ad36-d83cf7415be6.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/0e4f5b45-1fa4-406b-8ed8-d5ced6374c0d.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/2ac47932-d7e2-4ac2-a7c6-6a9be0c4abcd.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/14a42065-b678-4720-805e-7540d232df8c.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f9c99896-bcb6-45b4-9128-528f695e3628.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/03e4827c-7338-4de3-9ac6-8831ba5637e9.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/03cf6091-89c8-4ea2-a3d5-7ce26cc422cb.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/2456fcb4-82bd-4fa9-8ef2-8e1250c3ff50.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/fbde1e4d-650b-4ac5-8921-65510589656c.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/205f5b04-b42a-4890-af36-0ed2de7a56a1.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f652df75-c199-44a9-870b-54f68aae814d.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/2af2646f-3cc0-4ef2-a9e4-0beea36f335a.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/02b7b018-0fed-44c2-a9c2-93b2b3952efc.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/19c705ea-6af7-48f2-a2e7-f500ef840280.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/0da8c767-77b7-4c69-98d4-2c5c91b9affc.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f760c946-a103-4991-a6e5-ff60c24cd99f.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/2a9035ed-ec09-404d-adc3-d37688adf50a.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/10f2cb81-ad90-4857-a2f7-18e7d8f66907.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/0488a028-fb77-46e1-85fb-f0b86cf57fee.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/29cfef18-40c3-489f-adcf-05bd93765b9d.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f8767c5d-9024-43d9-9044-843f2cec00c7.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/19a62d7a-3d7d-4b5b-8dca-3247af94f339.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f3b1b61e-693d-4fee-b67b-fa4f09554391.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/27feebaa-f4dc-4c68-9348-f0ff35134e43.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/2c376b9a-167a-43d3-bcc2-b4af32fb9f74.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/27fa7496-e222-4016-8d1a-5a8dd4db52ed.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/254d15d9-dfc5-42a2-b2d6-f208527d6396.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/c059ced8-e99a-4fff-a734-b01cae2491bb.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f23bbee6-567d-4ef8-8b29-2ecb12a45be1.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f27252da-ac5d-46b2-8df9-32e09763574b.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f2fda506-7c73-4746-a7a6-59968f1e8de2.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/1ffee791-10f6-4b8f-bfcd-35220e8e0003.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/0361ea80-0215-4bbe-9bca-908ea7c4f8b6.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f88e605a-a637-4df6-a153-5c51bb304a73.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/fe83e190-f2d6-4998-9f82-b1ccd5bcb863.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/c1415e26-fddf-4a0c-a7eb-7b9a0d9e9983.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/02cfa7d1-61e0-4d9e-8664-9a7469ccab76.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/fdd20e4d-879e-4ff9-bc4e-8ec4184cfff9.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f9bf7579-e589-4953-bd68-d92f44f0aa95.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f3aa1daa-4873-446a-a5b7-7da7f955245e.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/0ff5bf5b-6af7-4537-90d0-1c47058d0627.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/0550968f-5ad7-460c-96c5-c2702535e344.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f7856767-112d-4ff6-8b20-1188c0c47a1a.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f5848669-b012-4685-9bc2-3c76680f7289.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/1c0a780d-1cac-4eee-b46d-470ecebc9ae0.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f5fb166f-fbb1-474f-a7ad-1677dc6d60a7.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/fc412463-62af-401b-aa44-3caef9de2352.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/fa42a65d-581e-44bf-a8de-b89e9a6c17fb.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f67d2434-0c18-441e-9ed4-66af65f511f7.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/10b1ae91-9c1a-4b1d-b269-51754df1b4f6.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/fd8de63f-e006-4e20-a937-9ecbde6e31e9.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/fc753cd9-e419-4baa-8233-008548b8aa3a.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/1a42aa5f-54c6-4ada-b381-cdf65cfc69b1.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/11e431ff-c6b8-45f1-9635-a055fbc90111.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/c1628c47-5ba3-42dd-8df3-7ad3abd57ad0.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f3142a9f-b625-41d9-a7b7-9a4aba0c2abb.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/fa2e48d0-4326-48e9-bb10-9ee2d6600f9e.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/2d0ebb7e-9c57-4a78-9728-e79b0f2bc91c.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f31a958a-66bf-4ccc-9fd7-79bbb9d17e7a.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/11a4ad3f-7899-4c3c-a88d-f1c799ec04df.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/2bd2356b-305a-4726-9a47-034da8f5f2ee.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/1505f53a-4da5-416e-a279-66849672051c.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/fef7b294-017c-4491-9e57-119086855785.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/2f51b8c1-32f8-4df8-af1e-d32c8dddad6f.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/f2e71eff-2656-4b52-a014-eea3d0d00efc.npy
#   inflating: 04-Pneumonia-Classification copy/Processed/val/1/26df5099-c051-41e9-929d-99b6f1684815.npy

# %%
labels.head(6)
# Out:
#                               patientId      x      y  width  height  Target
# 0  0004cfab-14fd-4e49-80ba-63a80b6bddd6    NaN    NaN    NaN     NaN       0
# 1  00313ee0-9eaa-42f4-b0ab-c148ed3241cd    NaN    NaN    NaN     NaN       0
# 2  00322d4d-1c29-4943-afc9-b6754be640eb    NaN    NaN    NaN     NaN       0
# 3  003d8fa0-6bf1-40ed-b54c-ac657f8495c5    NaN    NaN    NaN     NaN       0
# 4  00436515-870c-4b36-a041-de91049b9ab4  264.0  152.0  213.0   379.0       1
# 5  00436515-870c-4b36-a041-de91049b9ab4  562.0  152.0  256.0   453.0       1

# %% [markdown]
# # New section

# %%
# Remove duplicate entries
labels = labels.drop_duplicates("patientId")

# %%
labels.head()
# Out:
#                               patientId      x      y  width  height  Target
# 0  0004cfab-14fd-4e49-80ba-63a80b6bddd6    NaN    NaN    NaN     NaN       0
# 1  00313ee0-9eaa-42f4-b0ab-c148ed3241cd    NaN    NaN    NaN     NaN       0
# 2  00322d4d-1c29-4943-afc9-b6754be640eb    NaN    NaN    NaN     NaN       0
# 3  003d8fa0-6bf1-40ed-b54c-ac657f8495c5    NaN    NaN    NaN     NaN       0
# 4  00436515-870c-4b36-a041-de91049b9ab4  264.0  152.0  213.0   379.0       1

# %% [markdown]
# Let's define the path to the dicom files and also the path were we want to store our processed npy files

# %%
ROOT_PATH = Path("/content/04-Pneumonia-Classification copy/rsna-pneumonia-detection-challenge/stage_2_train_images/")
SAVE_PATH = Path("Processed/")

# %% [markdown]
# Let's look at some example images

# %%
fig, axis = plt.subplots(3, 3, figsize=(9, 9))
c = 0
for i in range(3):
    for j in range(3):
        patient_id = labels.patientId.iloc[c]
        dcm_path = ROOT_PATH/patient_id
        dcm_path = dcm_path.with_suffix(".dcm")
        dcm = pydicom.read_file(dcm_path).pixel_array
        
        
        label = labels["Target"].iloc[c]
        
        axis[i][j].imshow(dcm, cmap="bone")
        axis[i][j].set_title(label)
        c+=1

# %% [markdown]
# ## Dicom Reading & Effective storage
#
# In order to efficiently handle our data in the Dataloader, we convert the X-Ray images stored in the DICOM format to numpy arrays. Afterwards we compute the overall mean and standard deviation of the pixels of the whole dataset, for the purpose of normalization.
# Then the created numpy images are stored in two separate folders according to their binary label:
# * 0: All X-Rays which do not show signs of pneumonia
# * 1: All X-Rays which show signs of pneumonia

# %% [markdown]
# To do so, we iterate over the patient ids and concat the patient ID with the ROOT_PATH.
#
# We then directly save the standardized and resized files into the corresponding directory (0 for healthy, 1 for pneumonia).
# This allows to take advantage of the ready-to-use torchvision **DatasetFolder** for simple file reading
#
#
# We standardize all images by the maximum pixel value in the provided dataset, 255.
# All images are resized to 224x224.
#
# To compute dataset mean and standard deviation, we compute the sum of the pixel values as well as the sum of the squared pixel values for each subject.
# This allows to compute the overall mean and standard deviation without keeping the whole dataset in memory.

# %%
sums = 0
sums_squared = 0

for c, patient_id in enumerate(tqdm(labels.patientId)):
    dcm_path = ROOT_PATH/patient_id  # Create the path to the dcm file
    dcm_path = dcm_path.with_suffix(".dcm")  # And add the .dcm suffix
    
    # Read the dicom file with pydicom and standardize the array
    dcm = pydicom.read_file(dcm_path).pixel_array / 255  
        
    # Resize the image as 1024x1024 is way to large to be handeled by Deep Learning models at the moment
    # Let's use a shape of 224x224
    # In order to use less space when storing the image we convert it to float16
    dcm_array = cv2.resize(dcm, (224, 224)).astype(np.float16)
    
    # Retrieve the corresponding label
    label = labels.Target.iloc[c]
    
    # 4/5 train split, 1/5 val split
    train_or_val = "train" if c < 24000 else "val" 
        
    current_save_path = SAVE_PATH/train_or_val/str(label) # Define save path and create if necessary
    current_save_path.mkdir(parents=True, exist_ok=True)
    np.save(current_save_path/patient_id, dcm_array)  # Save the array in the corresponding directory
    
    normalizer = dcm_array.shape[0] * dcm_array.shape[1]  # Normalize sum of image
    if train_or_val == "train":  # Only use train data to compute dataset statistics
        sums += np.sum(dcm_array) / normalizer
        sums_squared += (np.power(dcm_array, 2).sum()) / normalizer
# Out:
#   0%|          | 0/26684 [00:00<?, ?it/s]

# %%
mean = sums / 24000
std = np.sqrt(sums_squared / 24000 - (mean**2))

# %% [markdown]
# We will use mean and std later in the dataloader to normalize our data

# %%
print(f"Mean of Dataset: {mean}, STD: {std}")
# Out:
# Mean of Dataset: 0.4903962485384803, STD: 0.24795070634161256

# %%
pip install torchmetrics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchmetrics
#   Downloading torchmetrics-0.11.1-py3-none-any.whl (517 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 517.2/517.2 KB 31.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.8/dist-packages (from torchmetrics) (1.21.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torchmetrics) (4.5.0)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.8/dist-packages (from torchmetrics) (1.13.1+cu116)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from torchmetrics) (23.0)
# Installing collected packages: torchmetrics
# Successfully installed torchmetrics-0.11.1

# %%
pip install import-ipynb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting import-ipynb
#   Downloading import_ipynb-0.1.4-py3-none-any.whl (4.1 kB)
# Requirement already satisfied: IPython in /usr/local/lib/python3.8/dist-packages (from import-ipynb) (7.9.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.8/dist-packages (from import-ipynb) (5.7.3)
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/dist-packages (from IPython->import-ipynb) (2.6.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from IPython->import-ipynb) (0.2.0)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from IPython->import-ipynb) (4.8.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from IPython->import-ipynb) (2.0.10)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from IPython->import-ipynb) (0.7.5)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 27.3 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from IPython->import-ipynb) (4.4.2)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.8/dist-packages (from IPython->import-ipynb) (5.7.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.8/dist-packages (from IPython->import-ipynb) (57.4.0)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.8/dist-packages (from nbformat->import-ipynb) (5.2.0)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.8/dist-packages (from nbformat->import-ipynb) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.8/dist-packages (from nbformat->import-ipynb) (4.3.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->IPython->import-ipynb) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.19.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (22.2.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.8/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (5.10.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->IPython->import-ipynb) (0.2.6)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->IPython->import-ipynb) (1.15.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.8/dist-packages (from jupyter-core->nbformat->import-ipynb) (3.0.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect->IPython->import-ipynb) (0.7.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat->import-ipynb) (3.13.0)
# Installing collected packages: jedi, import-ipynb
# Successfully installed import-ipynb-0.1.4 jedi-0.18.2

# %%
pip install pytorch-lightning
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytorch-lightning
#   Downloading pytorch_lightning-1.9.2-py3-none-any.whl (826 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 826.2/826.2 KB 41.1 MB/s eta 0:00:00
# Collecting lightning-utilities>=0.6.0.post0
#   Downloading lightning_utilities-0.6.0.post0-py3-none-any.whl (18 kB)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.8/dist-packages (from pytorch-lightning) (1.13.1+cu116)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.8/dist-packages (from pytorch-lightning) (4.5.0)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.8/dist-packages (from pytorch-lightning) (4.64.1)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /usr/local/lib/python3.8/dist-packages (from pytorch-lightning) (2023.1.0)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.8/dist-packages (from pytorch-lightning) (1.21.6)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.8/dist-packages (from pytorch-lightning) (6.0)
# Requirement already satisfied: torchmetrics>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from pytorch-lightning) (0.11.1)
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.8/dist-packages (from pytorch-lightning) (23.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.8/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning) (3.8.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning) (2.25.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (6.0.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.3.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (22.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (1.8.2)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.8/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (3.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (4.0.0)
# Installing collected packages: lightning-utilities, pytorch-lightning
# Successfully installed lightning-utilities-0.6.0.post0 pytorch-lightning-1.9.2

# %%
import torch
import torchvision
from torchvision import transforms
import torchmetrics
import pytorch_lightning as pl
from pytorch_lightning.callbacks import ModelCheckpoint
from pytorch_lightning.loggers import TensorBoardLogger
from tqdm.notebook import tqdm
import numpy as np
import matplotlib.pyplot as plt

# %%
def load_file(path):
    return np.load(path).astype(np.float32)

# %%
train_transforms = transforms.Compose([
                                    transforms.ToTensor(),  # Convert numpy array to tensor
                                    transforms.Normalize([0.49], [0.248]),  # Use mean and std from preprocessing notebook
                                    transforms.RandomAffine( # Data Augmentation
                                        degrees=(-5.0, 5.0),
                                    translate=(0.0, 0.05), scale=(0.9, 1.1)),
                                    transforms.RandomResizedCrop((224, 224), scale=(0.35, 1))

])

val_transforms = transforms.Compose([
                                    transforms.ToTensor(),  # Convert numpy array to tensor
                                    transforms.Normalize([0.49], [0.248]),  # Use mean and std from preprocessing notebook
])

# %%
train_dataset = torchvision.datasets.DatasetFolder(
    "Processed/train/",
    loader=load_file, extensions="npy", transform=train_transforms)

val_dataset = torchvision.datasets.DatasetFolder(
    "Processed/val/",
    loader=load_file, extensions="npy", transform=val_transforms)

# %%
train_dataset[0]
# Out:
# (tensor([[[ 0.4183,  0.5853,  0.7834,  ..., -0.5188, -0.4548, -0.4076],
#           [ 0.5751,  0.6488,  0.7240,  ..., -0.5452, -0.4778, -0.4271],
#           [ 0.5954,  0.6202,  0.6336,  ..., -0.5205, -0.4760, -0.4423],
#           ...,
#           [ 1.0855,  1.0415,  0.9819,  ...,  1.4637,  1.4658,  1.4677],
#           [ 1.0659,  1.0515,  1.0318,  ...,  1.3400,  1.3546,  1.3673],
#           [ 1.0504,  1.0595,  1.0717,  ...,  1.1987,  1.2349,  1.2650]]]), 0)

# %%
fig, axis = plt.subplots(2, 2, figsize=(9, 9))
for i in range(2):
    for j in range(2):
        random_index = np.random.randint(0, 100)
        x_ray, label =train_dataset[random_index]
        axis[i][j].imshow(x_ray[0], cmap="bone")
        axis[i][j].set_title(f"Label:{label}")

# %%
batch_size = 64#TODO
num_workers = 2# TODO

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, num_workers=num_workers, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, num_workers=num_workers, shuffle=False)

print(f"There are {len(train_dataset)} train images and {len(val_dataset)} val images")
# Out:
# There are 24000 train images and 2684 val images

# %%
np.unique(train_dataset.targets, return_counts=True), np.unique(val_dataset.targets, return_counts=True)
# Out:
# ((array([0, 1]), array([18593,  5407])), (array([0, 1]), array([2079,  605])))

# %%
#%% Model
class PneumoniaModel(pl.LightningModule):
    def __init__(self, weight=1):
        super().__init__()
        
        self.model = torchvision.models.resnet18()
        # change conv1 from 3 to 1 input channels
        self.model.conv1 = torch.nn.Conv2d(1, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
        # change out_feature of the last fully connected layer (called fc in resnet18) from 1000 to 1
        self.model.fc = torch.nn.Linear(in_features=512, out_features=1)
        
        self.optimizer = torch.optim.Adam(self.model.parameters(), lr=1e-4)
        self.loss_fn = torch.nn.BCEWithLogitsLoss(pos_weight=torch.tensor([weight]))
        
        # simple accuracy computation
        self.train_acc = torchmetrics.Accuracy(task='binary')
        self.val_acc = torchmetrics.Accuracy(task='binary')

    def forward(self, data):
        pred = self.model(data)
        return pred
    
    def training_step(self, batch, batch_idx):
        x_ray, label = batch
        label = label.float()  # Convert label to float (just needed for loss computation)
        pred = self(x_ray)[:,0]  # Prediction: Make sure prediction and label have same shape
        loss = self.loss_fn(pred, label)  # Compute the loss
        
        # Log loss and batch accuracy
        self.log("Train Loss", loss)
        self.log("Step Train Acc", self.train_acc(torch.sigmoid(pred), label.int()))
        return loss
    
    
    def training_epoch_end(self, outs):
        # After one epoch compute the whole train_data accuracy
        self.log("Train Acc", self.train_acc.compute())
        
        
    def validation_step(self, batch, batch_idx):
        # Same steps as in the training_step
        x_ray, label = batch
        label = label.float()
        pred = self(x_ray)[:,0]  # make sure prediction and label have same shape

        loss = self.loss_fn(pred, label)
        
        # Log validation metrics
        self.log("Val Loss", loss)
        self.log("Step Val Acc", self.val_acc(torch.sigmoid(pred), label.int()))
        return loss
    
    def validation_epoch_end(self, outs):
        self.log("Val Acc", self.val_acc.compute())
    
    def configure_optimizers(self):
        #Caution! You always need to return a list here (just pack your optimizer into one :))
        return [self.optimizer]

# %%
model = PneumoniaModel()  # Instanciate the model

# %%
checkpoint_callback = ModelCheckpoint(
    monitor='Val Acc',
    save_top_k=10,
    mode='max')

# %%
gpus = 1 #TODO
trainer = pl.Trainer(gpus=gpus, logger=TensorBoardLogger(save_dir="/content/04-Pneumonia-Classification copy/logs"), log_every_n_steps=1,
                     callbacks=checkpoint_callback,
                     max_epochs=35,devices=4, accelerator="gpu")
# Out:
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py:474: LightningDeprecationWarning: Setting `Trainer(gpus=1)` is deprecated in v1.7 and will be removed in v2.0. Please use `Trainer(accelerator='gpu', devices=1)` instead.
#   rank_zero_deprecation(
# /usr/local/lib/python3.8/dist-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py:494: UserWarning: The flag `devices=4` will be ignored, instead the device specific number 1 will be used
#   rank_zero_warn(
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs

# %%
trainer.fit(model, train_loader, val_loader)
# Out:
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name      | Type              | Params
# ------------------------------------------------
# 0 | model     | ResNet            | 11.2 M
# 1 | loss_fn   | BCEWithLogitsLoss | 0
# 2 | train_acc | BinaryAccuracy    | 0
# 3 | val_acc   | BinaryAccuracy    | 0
# ------------------------------------------------
# 11.2 M    Trainable params
# 0         Non-trainable params
# 11.2 M    Total params
# 44.683    Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=35` reached.

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
model = PneumoniaModel.load_from_checkpoint("/content/04-Pneumonia-Classification copy/weights/weights_1.ckpt")
model.eval()
model.to(device);
# Out:
# INFO:pytorch_lightning.utilities.migration.utils:Lightning automatically upgraded your loaded checkpoint from v1.3.4 to v1.9.2. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file 04-Pneumonia-Classification copy/weights/weights_1.ckpt`

# %%
preds = []
labels = []

with torch.no_grad():
    for data, label in tqdm(val_dataset):
        data = data.to(device).float().unsqueeze(0)
        pred = torch.sigmoid(model(data)[0].cpu())
        preds.append(pred)
        labels.append(label)
preds = torch.tensor(preds)
labels = torch.tensor(labels).int()
# Out:
#   0%|          | 0/2684 [00:00<?, ?it/s]

# %%
acc = torchmetrics.Accuracy(task="binary")(preds, labels)
precision = torchmetrics.Precision(task="binary")(preds, labels)
recall = torchmetrics.Recall(task="binary")(preds, labels)
cm = torchmetrics.ConfusionMatrix(num_classes=2, task="binary")(preds, labels)
cm_threshed = torchmetrics.ConfusionMatrix(num_classes=2, threshold=0.25, task="binary")(preds, labels)

print(f"Val Accuracy: {acc}")
print(f"Val Precision: {precision}")
print(f"Val Recall: {recall}")
print(f"Confusion Matrix:\n {cm}")
print(f"Confusion Matrix 2:\n {cm_threshed}")
# Out:
# Val Accuracy: 0.8457525968551636
# Val Precision: 0.7002096176147461
# Val Recall: 0.5520660877227783
# Confusion Matrix:
#  tensor([[1936,  143],
#         [ 271,  334]])
# Confusion Matrix 2:
#  tensor([[1725,  354],
#         [ 136,  469]])

# %%
fig, axis = plt.subplots(3, 3, figsize=(9, 9))

for i in range(3):
    for j in range(3):
        rnd_idx = np.random.randint(0, len(preds))
        axis[i][j].imshow(val_dataset[rnd_idx][0][0], cmap="bone")
        axis[i][j].set_title(f"Pred:{int(preds[rnd_idx] > 0.5)}, Label:{labels[rnd_idx]}")
        axis[i][j].axis("off")
